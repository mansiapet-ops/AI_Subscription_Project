# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\shrad\OneDrive\Desktop\lp5\goog1.csv")

df.head()
# Out:
#          Date        Open        High         Low       Close   Volume
# 0  12/19/2016  790.219971  797.659973  786.270020  794.200012  1225900
# 1  12/20/2016  796.760010  798.650024  793.270020  796.419983   925100
# 2  12/21/2016  795.840027  796.676025  787.099976  794.559998  1208700
# 3  12/22/2016  792.359985  793.320007  788.580017  791.260010   969100
# 4  12/23/2016  790.900024  792.739990  787.280029  789.909973   623400

# %%
df_req = df['Close']

# %%
plt.plot(df_req)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
df_req = scaler.fit_transform(np.array(df_req).reshape(-1,1))

training_size = int(len(df_req)*0.8)
df_train = df_req[:training_size, :]
df_test = df_req[training_size:len(df_req), :]

# %%
def create_dataset(data, step=4):
    X = []
    y = []
    for i in range(len(data)-step):
        X.append(data[i:i+step, :])
        y.append(data[i, :])

    return np.array(X), np.array(y)

x_train, y_train = create_dataset(df_train)
x_test, y_test = create_dataset(df_test)

# %%
x_train
# Out:
# array([[[0.27870496],
#         [0.30635093],
#         [0.28318798],
#         [0.24209223]],
#
#        [[0.30635093],
#         [0.28318798],
#         [0.24209223],
#         [0.22527981]],
#
#        [[0.28318798],
#         [0.24209223],
#         [0.22527981],
#         [0.24570341]],
#
#        [[0.24209223],
#         [0.22527981],
#         [0.24570341],
#         [0.16475695]],
#
#        [[0.22527981],
#         [0.24570341],
#         [0.16475695],
#         [0.13661236]],
#
#        [[0.24570341],
#         [0.16475695],
#         [0.13661236],
#         [0.        ]],
#
#        [[0.16475695],
#         [0.13661236],
#         [0.        ],
#         [0.17833138]],
#
#        [[0.13661236],
#         [0.        ],
#         [0.17833138],
#         [0.18779601]],
#
#        [[0.        ],
#         [0.17833138],
#         [0.18779601],
#         [0.27646347]],
#
#        [[0.17833138],
#         [0.18779601],
#         [0.27646347],
#         [0.42752207]],
#
#        [[0.18779601],
#         [0.27646347],
#         [0.42752207],
#         [0.43374872]],
#
#        [[0.27646347],
#         [0.42752207],
#         [0.43374872],
#         [0.41058501]],
#
#        [[0.42752207],
#         [0.43374872],
#         [0.41058501],
#         [0.44943925]],
#
#        [[0.43374872],
#         [0.41058501],
#         [0.44943925],
#         [0.43013678]],
#
#        [[0.41058501],
#         [0.44943925],
#         [0.43013678],
#         [0.44906604]],
#
#        [[0.44943925],
#         [0.43013678],
#         [0.44906604],
#         [0.4083435 ]],
#
#        [[0.43013678],
#         [0.44906604],
#         [0.4083435 ],
#         [0.42652559]],
#
#        [[0.44906604],
#         [0.4083435 ],
#         [0.42652559],
#         [0.37801975]],
#
#        [[0.4083435 ],
#         [0.42652559],
#         [0.37801975],
#         [0.41344979]],
#
#        [[0.42652559],
#         [0.37801975],
#         [0.41344979],
#         [0.5914072 ]],
#
#        [[0.37801975],
#         [0.41344979],
#         [0.5914072 ],
#         [0.64819422]],
#
#        [[0.41344979],
#         [0.5914072 ],
#         [0.64819422],
#         [0.79514303]],
#
#        [[0.5914072 ],
#         [0.64819422],
#         [0.79514303],
#         [0.75130792]],
#
#        [[0.64819422],
#         [0.79514303],
#         [0.75130792],
#         [0.64122041]],
#
#        [[0.79514303],
#         [0.75130792],
#         [0.64122041],
#         [0.37982571]],
#
#        [[0.75130792],
#         [0.64122041],
#         [0.37982571],
#         [0.31095859]],
#
#        [[0.64122041],
#         [0.37982571],
#         [0.31095859],
#         [0.29732258]],
#
#        [[0.37982571],
#         [0.31095859],
#         [0.29732258],
#         [0.33262797]],
#
#        [[0.31095859],
#         [0.29732258],
#         [0.33262797],
#         [0.36948926]],
#
#        [[0.29732258],
#         [0.33262797],
#         [0.36948926],
#         [0.36762172]],
#
#        [[0.33262797],
#         [0.36948926],
#         [0.36762172],
#         [0.43773312]],
#
#        [[0.36948926],
#         [0.36762172],
#         [0.43773312],
#         [0.4552927 ]],
#
#        [[0.36762172],
#         [0.43773312],
#         [0.4552927 ],
#         [0.4699875 ]],
#
#        [[0.43773312],
#         [0.4552927 ],
#         [0.4699875 ],
#         [0.52117039]],
#
#        [[0.4552927 ],
#         [0.4699875 ],
#         [0.52117039],
#         [0.59053537]],
#
#        [[0.4699875 ],
#         [0.52117039],
#         [0.59053537],
#         [0.60560414]],
#
#        [[0.52117039],
#         [0.59053537],
#         [0.60560414],
#         [0.58729739]],
#
#        [[0.59053537],
#         [0.60560414],
#         [0.58729739],
#         [0.6518054 ]],
#
#        [[0.60560414],
#         [0.58729739],
#         [0.6518054 ],
#         [0.70049824]],
#
#        [[0.58729739],
#         [0.6518054 ],
#         [0.70049824],
#         [0.74520517]],
#
#        [[0.6518054 ],
#         [0.70049824],
#         [0.74520517],
#         [0.73399766]],
#
#        [[0.70049824],
#         [0.74520517],
#         [0.73399766],
#         [0.74109613]],
#
#        [[0.74520517],
#         [0.73399766],
#         [0.74109613],
#         [0.70759672]],
#
#        [[0.73399766],
#         [0.74109613],
#         [0.70759672],
#         [0.71556701]]])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM

model = Sequential()
model.add(LSTM(128, return_sequences=True, input_shape=(x_train.shape[1], 1)))
model.add(LSTM(32))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')
# Out:
# C:\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
model.fit(x_train, y_train, epochs=50)
# Out:
# Epoch 1/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 26s 405ms/step - loss: 0.2090
# Epoch 2/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 260ms/step - loss: 0.1671
# Epoch 3/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 293ms/step - loss: 0.1287
# Epoch 4/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 225ms/step - loss: 0.0897
# Epoch 5/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - loss: 0.0590
# Epoch 6/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 237ms/step - loss: 0.0304
# Epoch 7/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 255ms/step - loss: 0.0129
# Epoch 8/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 233ms/step - loss: 0.0088
# Epoch 9/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 320ms/step - loss: 0.0177
# Epoch 10/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 319ms/step - loss: 0.0246
# Epoch 11/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 391ms/step - loss: 0.0210
# Epoch 12/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 331ms/step - loss: 0.0132
# Epoch 13/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 285ms/step - loss: 0.0085
# Epoch 14/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 298ms/step - loss: 0.0078
# Epoch 15/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 302ms/step - loss: 0.0091
# Epoch 16/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 533ms/step - loss: 0.0103
# Epoch 17/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 511ms/step - loss: 0.0108
# Epoch 18/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 315ms/step - loss: 0.0101
# Epoch 19/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 302ms/step - loss: 0.0087
# Epoch 20/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 323ms/step - loss: 0.0077
# Epoch 21/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 348ms/step - loss: 0.0066
# Epoch 22/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 285ms/step - loss: 0.0065
# Epoch 23/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 295ms/step - loss: 0.0070
# Epoch 24/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 258ms/step - loss: 0.0072
# Epoch 25/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 353ms/step - loss: 0.0070
# Epoch 26/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 282ms/step - loss: 0.0063
# Epoch 27/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 260ms/step - loss: 0.0058
# Epoch 28/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 223ms/step - loss: 0.0056
# Epoch 29/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 301ms/step - loss: 0.0054
# Epoch 30/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 636ms/step - loss: 0.0054
# Epoch 31/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 361ms/step - loss: 0.0053
# Epoch 32/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 347ms/step - loss: 0.0051
# Epoch 33/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 433ms/step - loss: 0.0048
# Epoch 34/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 284ms/step - loss: 0.0046
# Epoch 35/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 337ms/step - loss: 0.0046
# Epoch 36/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 338ms/step - loss: 0.0045
# Epoch 37/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 430ms/step - loss: 0.0043
# Epoch 38/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 389ms/step - loss: 0.0042
# Epoch 39/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 591ms/step - loss: 0.0040
# Epoch 40/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 312ms/step - loss: 0.0039
# Epoch 41/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 272ms/step - loss: 0.0039
# Epoch 42/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 449ms/step - loss: 0.0038
# Epoch 43/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 327ms/step - loss: 0.0037
# Epoch 44/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 308ms/step - loss: 0.0036
# Epoch 45/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 317ms/step - loss: 0.0036
# Epoch 46/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 303ms/step - loss: 0.0036
# Epoch 47/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 277ms/step - loss: 0.0035
# Epoch 48/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 295ms/step - loss: 0.0035
# Epoch 49/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 446ms/step - loss: 0.0035
# Epoch 50/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 390ms/step - loss: 0.0034

# %%
metrics = model.evaluate(x_test, y_test)
metrics
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step - loss: 0.0012
# 0.0012355982325971127

# %%
y_pred = scaler.inverse_transform(model.predict(x_test))
y_test = scaler.inverse_transform(y_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step

# %%
plt.plot(y_pred, label="Predicted")
plt.plot(y_test, label="Actual")
plt.legend()
